# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars2020 = pd.read_csv("https://raw.githubusercontent.com/thisisdaryn/data/master/ML/cars2020.csv")
sns.pairplot(cars2020, hue="transmission")

# %% [markdown]
# ### Insert Summary table 1: aggregating different transmission types by manufacturer

# %% [markdown]
# ### Insert Summary table 2: Aggregating totals of different classes of cars by main manufacturers

# %% [markdown]
# ### Plot involving a categorical variable: e.g. box plot showing mpg range for different transmission types
